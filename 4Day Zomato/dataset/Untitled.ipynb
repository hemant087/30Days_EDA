# %%
import pandas as pd

# %%
df = pd.read_json("file1.json")

# %%
df.head()
# Out:
#    results_found                                        restaurants  \
# 0        17151.0  [{'restaurant': {'has_online_delivery': 1, 'ph...
# 1         4748.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 2        13786.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 3        10224.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 4         7039.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
#
#    results_shown  results_start message  code status
# 0           20.0            1.0     NaN   NaN    NaN
# 1           20.0            1.0     NaN   NaN    NaN
# 2           20.0            1.0     NaN   NaN    NaN
# 3           20.0            1.0     NaN   NaN    NaN
# 4           20.0            1.0     NaN   NaN    NaN

# %%
df.loc[0,"restaurants"]
# Out:
# [{'restaurant': {'has_online_delivery': 1,
#    'photos_url': 'https://www.zomato.com/HauzKhasSocial/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#    'url': 'https://www.zomato.com/HauzKhasSocial?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'price_range': 3,
#    'apikey': 'b90e6a8c738410315a20c449fe2eb1b1',
#    'user_rating': {'rating_text': 'Very Good',
#     'rating_color': '5BA829',
#     'votes': '7931',
#     'aggregate_rating': '4.3'},
#    'R': {'res_id': 308322},
#    'name': 'Hauz Khas Social',
#    'cuisines': 'Continental, American, Asian, North Indian',
#    'is_delivering_now': 0,
#    'deeplink': 'zomato://restaurant/308322',
#    'menu_url': 'https://www.zomato.com/HauzKhasSocial/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#    'average_cost_for_two': 1600,
# ...

# %%
df["results_found"].value_counts()
# Out:
# results_found
# 0.0        17
# 17151.0     1
# 3313.0      1
# 473.0       1
# 591.0       1
# 272.0       1
# 302.0       1
# 8200.0      1
# 5778.0      1
# 1956.0      1
# 4033.0      1
# 1738.0      1
# 29441.0     1
# 6528.0      1
# 27488.0     1
# 14431.0     1
# 547.0       1
# 3816.0      1
# 4316.0      1
# 1826.0      1
# 15342.0     1
# 3180.0      1
# 2915.0      1
# 6347.0      1
# 1950.0      1
# 5462.0      1
# 4864.0      1
# 24595.0     1
# 1454.0      1
# 448.0       1
# 498.0       1
# 4748.0      1
# 327.0       1
# 13786.0     1
# 10224.0     1
# 7039.0      1
# 5678.0      1
# 5374.0      1
# 1382.0      1
# 1534.0      1
# 2206.0      1
# 2974.0      1
# 1831.0      1
# 2416.0      1
# 1016.0      1
# 557.0       1
# 1135.0      1
# 738.0       1
# 379.0       1
# 513.0       1
# 340.0       1
# 363.0       1
# 610.0       1
# 256.0       1
# 790.0       1
# 600.0       1
# 1582.0      1
# 382.0       1
# 632.0       1
# 2286.0      1
# ...

# %%
df.isnull().sum()
# Out:
# results_found    403
# restaurants      403
# results_shown    403
# results_start    403
# message           76
# code              76
# status            76
# dtype: int64

# %%
pd.read_json("file2.json").isnull().sum()
# Out:
# results_found    0
# results_start    0
# results_shown    0
# restaurants      0
# dtype: int64

# %%
pd.read_json("file3.json").head()
# Out:
#    results_found  results_start  results_shown  \
# 0      1263908.0           41.0           20.0
# 1      1263908.0           41.0           20.0
# 2      1263908.0           41.0           20.0
# 3      1263908.0           41.0           20.0
# 4      1263908.0           41.0           20.0
#
#                                          restaurants  code status message
# 0  [{'restaurant': {'R': {'res_id': 2100702}, 'ap...   NaN    NaN     NaN
# 1  [{'restaurant': {'R': {'res_id': 2100702}, 'ap...   NaN    NaN     NaN
# 2  [{'restaurant': {'R': {'res_id': 2100702}, 'ap...   NaN    NaN     NaN
# 3  [{'restaurant': {'R': {'res_id': 2100702}, 'ap...   NaN    NaN     NaN
# 4  [{'restaurant': {'R': {'res_id': 2100702}, 'ap...   NaN    NaN     NaN

# %%
pd.read_json("file4.json").head()
# Out:
#    results_found  results_start  results_shown  \
# 0        1263908             61             20
# 1        1263908             61             20
# 2        1263908             61             20
# 3        1263908             61             20
# 4        1263908             61             20
#
#                                          restaurants
# 0  [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# 1  [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# 2  [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# 3  [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# 4  [{'restaurant': {'R': {'res_id': 16604370}, 'a...

# %%
pd.read_json("file5.json").head()
# Out:
#    results_found                                        restaurants  \
# 0            0.0                                                 []
# 1         6835.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 2            0.0                                                 []
# 3            0.0                                                 []
# 4         8680.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
#
#    results_shown  results_start message  code status
# 0            0.0            1.0     NaN   NaN    NaN
# 1           20.0            1.0     NaN   NaN    NaN
# 2            0.0            1.0     NaN   NaN    NaN
# 3            0.0            1.0     NaN   NaN    NaN
# 4           20.0            1.0     NaN   NaN    NaN

# %%
df.merge(pd.read_json("file2.json"),on="results_found").merge(pd.read_json("file3.json"),on="results_found")
# Out:
#       results_found                                      restaurants_x  \
# 0           17151.0  [{'restaurant': {'has_online_delivery': 1, 'ph...
# 1           17151.0  [{'restaurant': {'has_online_delivery': 1, 'ph...
# 2           17151.0  [{'restaurant': {'has_online_delivery': 1, 'ph...
# 3           17151.0  [{'restaurant': {'has_online_delivery': 1, 'ph...
# 4           17151.0  [{'restaurant': {'has_online_delivery': 1, 'ph...
# ...             ...                                                ...
# 8525        17151.0  [{'restaurant': {'has_online_delivery': 1, 'ph...
# 8526        17151.0  [{'restaurant': {'has_online_delivery': 1, 'ph...
# 8527        17151.0  [{'restaurant': {'has_online_delivery': 1, 'ph...
# 8528          363.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 8529          302.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
#
#       results_shown_x  results_start_x message_x  code_x status_x  \
# ...

# %%
import matplotlib.pyplot as plt

# Example data
categories = ['A', 'B', 'C', 'D']
values = [50, 30, 20]

# Calculate percentages
total = sum(values)
percentages = [(v / total) * 100 for v in values]

# Plotting
fig, ax = plt.subplots()
bars = ax.bar(categories, values, color='skyblue')

# Add percentage labels on top
for bar, pct in zip(bars, percentages):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height,
            f'{pct:.1f}%', ha='center', va='bottom', fontsize=10)

# Optional: Add labels and title
ax.set_ylabel('Values')
ax.set_title('Bar Chart with Percentage Labels')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 13
#      11 # Plotting
#      12 fig, ax = plt.subplots()
# ---> 13 bars = ax.bar(categories, values, color='skyblue')
#      15 # Add percentage labels on top
#      16 for bar, pct in zip(bars, percentages):
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
# ...
